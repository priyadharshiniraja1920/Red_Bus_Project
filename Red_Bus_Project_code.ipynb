# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException, NoSuchElementException
import pandas as pd

# %% [markdown]
# ## LINKS

# %%
State_Links = ["https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/ksrtc-kerala/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/astc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile"]

# %% [markdown]
# ## 1. Andhra Pradesh State Road Transport Corporation (APSRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Andhra_link_route(path):
    LINKS_ANDHRA = []
    ROUTE_ANDHRA = []
    
    paths = driver.find_elements(By.XPATH, path)

    for i in range(1, 6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    LINKS_ANDHRA.append(href)
                text = link.text.strip()
                if text:
                    ROUTE_ANDHRA.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            actions = ActionChains(driver)
            actions.move_to_element(next_button).click().perform()

        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(LINKS_ANDHRA), list(ROUTE_ANDHRA)

LINKS_ANDHRA, ROUTE_ANDHRA = Andhra_link_route("//a[@class='route']")
# Out:
# No more pages to paginate at page 5.

# %%
AP_df=pd.DataFrame({"Route_Names":ROUTE_ANDHRA,"Route_Links":LINKS_ANDHRA})
AP_df
# Out:
#                                 Route_Names  \
# 0                   Hyderabad to Vijayawada
# 1                   Vijayawada to Hyderabad
# 2                 Kakinada to Visakhapatnam
# 3    Chittoor (Andhra Pradesh) to Bangalore
# 4                     Bangalore to Tirupati
# 5                     Tirupati to Bangalore
# 6                       Kadapa to Bangalore
# 7                       Hyderabad to Ongole
# 8   Anantapur (andhra pradesh) to Bangalore
# 9                       Bangalore to Kadapa
# 10                      Ongole to Hyderabad
# 11   Bangalore to Chittoor (Andhra Pradesh)
# 12  Bangalore to Anantapur (andhra pradesh)
# 13                Visakhapatnam to Kakinada
# 14                      Kadiri to Bangalore
# 15                   Vinukonda to Hyderabad
# 16                      Bangalore to Kadiri
# 17                Hyderabad to Narasaraopet
# 18                 Madanapalli to Bangalore
# 19                Narasaraopet to Hyderabad
# ...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/ap_df.csv"
AP_df.to_csv(path,index=False)

# %% [markdown]
# ## 2. Kerala State Road Transport Corporation (KSRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/ksrtc-kerala/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Kerala_Routes(path):
    KERALA_LINKS = []
    KERALA_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,3):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    KERALA_LINKS.append(href)
                text = link.text.strip()
                if text:
                    KERALA_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[9]/div[2]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(KERALA_LINKS) , list(KERALA_ROUTES)

KERALA_LINKS,KERALA_ROUTES = Kerala_Routes('//a[@class="route"]')

# %%
Kerala_df = pd.DataFrame({"Route_Names":KERALA_ROUTES,"Route_Links":KERALA_LINKS})
Kerala_df
# Out:
#                         Route_Names  \
# 0            Bangalore to Kozhikode
# 1            Kozhikode to Ernakulam
# 2            Kozhikode to Bangalore
# 3            Ernakulam to Kozhikode
# 4               Mysore to Kozhikode
# 5               Kozhikode to Mysore
# 6             Kozhikode to Thrissur
# 7   Kozhikode to Thiruvananthapuram
# 8             Kozhikode to Kottayam
# 9             Thrissur to Kozhikode
# 10           Bangalore to Kozhikode
# 11           Kozhikode to Ernakulam
# 12           Kozhikode to Bangalore
# 13           Ernakulam to Kozhikode
# 14              Mysore to Kozhikode
# 15              Kozhikode to Mysore
# 16            Kozhikode to Thrissur
# 17  Kozhikode to Thiruvananthapuram
# 18            Kozhikode to Kottayam
# 19            Thrissur to Kozhikode
#
#                                           Route_Links
# 0   https://www.redbus.in/bus-tickets/bangalore-to...
# 1   https://www.redbus.in/bus-tickets/kozhikode-to...
# ...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/Kerala_df.csv"
Kerala_df.to_csv(path,index=False)

# %% [markdown]
# ## 3. Telangana State Road Transport Corporation (TSRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Telangana_Routes(path):
    TELANGANA_LINKS = []
    TELANGANA_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,4):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    TELANGANA_LINKS.append(href)
                text = link.text.strip()
                if text:
                    TELANGANA_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[8]/div[3]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(TELANGANA_LINKS) , list(TELANGANA_ROUTES)

TELANGANA_LINKS,TELANGANA_ROUTES = Telangana_Routes("//a[@class='route']")
# Out:
# No more pages to paginate at page 1.

# %%
Telangana_df = pd.DataFrame({"Route_Names":TELANGANA_ROUTES,"Route_Links":TELANGANA_LINKS})
Telangana_df
# Out:
#                             Route_Names  \
# 0                  Khammam to Hyderabad
# 1               Hyderabad to Vijayawada
# 2                  Hyderabad to Khammam
# 3                Hyderabad to Srisailam
# 4               Karimnagar to Hyderabad
# 5                 Hyderabad to Adilabad
# 6               Kothagudem to Hyderabad
# 7               Hyderabad to Mancherial
# 8  Guntur (Andhra Pradesh) to Hyderabad
# 9            Godavarikhani to Hyderabad
#
#                                          Route_Links
# 0  https://www.redbus.in/bus-tickets/khammam-to-h...
# 1  https://www.redbus.in/bus-tickets/hyderabad-to...
# 2  https://www.redbus.in/bus-tickets/hyderabad-to...
# 3  https://www.redbus.in/bus-tickets/hyderabad-to...
# 4  https://www.redbus.in/bus-tickets/karimnagar-t...
# 5  https://www.redbus.in/bus-tickets/hyderabad-to...
# 6  https://www.redbus.in/bus-tickets/kothagudem-t...
# 7  https://www.redbus.in/bus-tickets/hyderabad-to...
# ...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/Telangana_df.csv"
Telangana_df.to_csv(path,index=False)

# %% [markdown]
# ## 4. Kadamba Transport Corporation Limited (KTCL)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Kadamba_Routes(path):
    KADAMBA_LINKS = []
    KADAMBA_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    KADAMBA_LINKS.append(href)
                text = link.text.strip()
                if text:
                    KADAMBA_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,"//*[@class='DC_117_paginationTable']")))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[7]/div[5]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(KADAMBA_LINKS) , list(KADAMBA_ROUTES)

KADAMBA_LINKS,KADAMBA_ROUTES = Kadamba_Routes('//a[@class="route"]')
# Out:
# No more pages to paginate at page 1.

# %%
Kadamba_df = pd.DataFrame({"Route_Names":KADAMBA_ROUTES,"Route_Links":KADAMBA_LINKS})
Kadamba_df
# Out:
#                     Route_Names  \
# 0                   Pune to Goa
# 1                   Goa to Pune
# 2                 Mumbai to Goa
# 3                 Goa to Mumbai
# 4               Belagavi to Goa
# 5              Bangalore to Goa
# 6              Goa to Bangalore
# 7             Pandharpur to Goa
# 8               Goa to Belagavi
# 9  Goa to Kolhapur(Maharashtra)
#
#                                          Route_Links
# 0      https://www.redbus.in/bus-tickets/pune-to-goa
# 1      https://www.redbus.in/bus-tickets/goa-to-pune
# 2    https://www.redbus.in/bus-tickets/mumbai-to-goa
# 3    https://www.redbus.in/bus-tickets/goa-to-mumbai
# 4  https://www.redbus.in/bus-tickets/belagavi-to-goa
# 5  https://www.redbus.in/bus-tickets/bangalore-to...
# 6  https://www.redbus.in/bus-tickets/goa-to-banga...
# 7  https://www.redbus.in/bus-tickets/pandharpur-t...
# 8  https://www.redbus.in/bus-tickets/goa-to-belagavi
# 9  https://www.redbus.in/bus-tickets/goa-to-kolha...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/Kadamba_df.csv"
Kadamba_df.to_csv(path,index=False)

# %% [markdown]
# ## 5. South Bengal State Transport Corporation (SBSTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def South_Bengal_Routes(path):
    SOUTH_BENGAL_LINKS = []
    SOUTH_BENGAL_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    SOUTH_BENGAL_LINKS.append(href)
                text = link.text.strip()
                if text:
                    SOUTH_BENGAL_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@class="DC_117_pageTabs DC_117_pageActive"]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(SOUTH_BENGAL_LINKS) , list(SOUTH_BENGAL_ROUTES)

SOUTH_BENGAL_LINKS,SOUTH_BENGAL_ROUTES = South_Bengal_Routes("//a[@class='route']")

# %%
SB_df = pd.DataFrame({"Route_Names":SOUTH_BENGAL_ROUTES,"Route_Links":SOUTH_BENGAL_LINKS})
SB_df
# Out:
#                           Route_Names  \
# 0   Durgapur (West Bengal) to Kolkata
# 1                  Kolkata to Burdwan
# 2   Kolkata to Durgapur (West Bengal)
# 3                   Haldia to Kolkata
# 4                   Kolkata to Haldia
# 5                Midnapore to Kolkata
# 6   Kolkata to Arambagh (West Bengal)
# 7                    Kolkata to Digha
# 8                    Digha to Kolkata
# 9                  Kolkata to Bankura
# 10  Durgapur (West Bengal) to Kolkata
# 11                 Kolkata to Burdwan
# 12  Kolkata to Durgapur (West Bengal)
# 13                  Haldia to Kolkata
# 14                  Kolkata to Haldia
# 15               Midnapore to Kolkata
# 16  Kolkata to Arambagh (West Bengal)
# 17                   Kolkata to Digha
# 18                   Digha to Kolkata
# 19                 Kolkata to Bankura
# 20  Durgapur (West Bengal) to Kolkata
# 21                 Kolkata to Burdwan
# 22  Kolkata to Durgapur (West Bengal)
# ...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/SB_df.csv"
SB_df.to_csv(path,index=False)

# %% [markdown]
# ## 6. Rajasthan State Road Transport Corporation (RSRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Rajasthan_Routes(path):
    RAJASTHAN_LINKS = []
    RAJASTHAN_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,3):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    RAJASTHAN_LINKS.append(href)
                text = link.text.strip()
                if text:
                    RAJASTHAN_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,"//*[@id='root']/div/div[4]/div[12]/div[2]")
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(RAJASTHAN_LINKS) , list(RAJASTHAN_ROUTES)

RAJASTHAN_LINKS,RAJASTHAN_ROUTES = Rajasthan_Routes('//a[@class="route"]')

# %%
Rajasthan_df = pd.DataFrame({"Route_Names":RAJASTHAN_ROUTES,"Route_Links":RAJASTHAN_LINKS})
Rajasthan_df
# Out:
#                                       Route_Names  \
# 0                                Jodhpur to Ajmer
# 1        Beawar (Rajasthan) to Jaipur (Rajasthan)
# 2                              Udaipur to Jodhpur
# 3                   Jaipur (Rajasthan) to Jodhpur
# 4                     Sikar to Jaipur (Rajasthan)
# 5   Aligarh (uttar pradesh) to Jaipur (Rajasthan)
# 6           Kota(Rajasthan) to Jaipur (Rajasthan)
# 7                    Jaipur (Rajasthan) to Pilani
# 8   Jaipur (Rajasthan) to Aligarh (uttar pradesh)
# 9                Kishangarh to Jaipur (Rajasthan)
# 10                               Sikar to Bikaner
# 11                  Jodhpur to Beawar (Rajasthan)
# 12                    Udaipur to Pali (Rajasthan)
# 13          Jaipur (Rajasthan) to Kota(Rajasthan)
# 14                     Kota(Rajasthan) to Udaipur
# 15                Jaipur (Rajasthan) to Bharatpur
# 16                  Jaipur (Rajasthan) to Mathura
# 17                               Bikaner to Sikar
# ...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/Rajasthan_df.csv"
Rajasthan_df.to_csv(path,index=False)

# %% [markdown]
# ## 7. Himachal Road Transport Corporation (HRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 30)

def Himachal_Routes(path):
    HIMACHAL_LINKS = []
    HIMACHAL_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,5):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    HIMACHAL_LINKS.append(href)
                text = link.text.strip()
                if text:
                    HIMACHAL_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[9]/div[4]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(HIMACHAL_LINKS) , list(HIMACHAL_ROUTES)

HIMACHAL_LINKS,HIMACHAL_ROUTES = Himachal_Routes('//a[@class="route"]')
# Out:
# No more pages to paginate at page 1.

# %%
Himachal_df = pd.DataFrame({"Route_Names":HIMACHAL_ROUTES,"Route_Links":HIMACHAL_LINKS})
Himachal_df
# Out:
#                                  Route_Names  \
# 0                            Delhi to Shimla
# 1  Hamirpur (Himachal Pradesh) to Chandigarh
# 2  Chandigarh to Hamirpur (Himachal Pradesh)
# 3                            Shimla to Delhi
# 4       Hamirpur (Himachal Pradesh) to Delhi
# 5       Delhi to Hamirpur (Himachal Pradesh)
# 6                       Kangra to Chandigarh
# 7    Chamba (Himachal Pradesh) to Chandigarh
# 8                        Delhi to Chandigarh
# 9                     Palampur to Chandigarh
#
#                                          Route_Links
# 0  https://www.redbus.in/bus-tickets/delhi-to-shimla
# 1  https://www.redbus.in/bus-tickets/hamirpur-him...
# 2  https://www.redbus.in/bus-tickets/chandigarh-t...
# 3  https://www.redbus.in/bus-tickets/shimla-to-delhi
# 4  https://www.redbus.in/bus-tickets/hamirpur-him...
# 5  https://www.redbus.in/bus-tickets/delhi-to-ham...
# 6  https://www.redbus.in/bus-tickets/kangra-to-ch...
# ...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/Himachal_df.csv"
Himachal_df.to_csv(path,index=False)

# %% [markdown]
# ## 8. Assam State Transport Corporation (ASTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/astc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Assam_Routes(path):
    ASSAM_LINKS = []
    ASSAM_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    ASSAM_LINKS.append(href)
                text = link.text.strip()
                if text:
                    ASSAM_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[9]/div[5]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(ASSAM_LINKS) , list(ASSAM_ROUTES)

ASSAM_LINKS,ASSAM_ROUTES = Assam_Routes("//a[@class='route']")
# Out:
# No more pages to paginate at page 1.

# %%
Assam_df = pd.DataFrame({"Route_Names":ASSAM_ROUTES,"Route_Links":ASSAM_LINKS})
Assam_df
# Out:
#                            Route_Names  \
# 0                   Tezpur to Guwahati
# 1                   Guwahati to Tezpur
# 2           Nagaon (Assam) to Guwahati
# 3           Guwahati to Nagaon (Assam)
# 4                 Goalpara to Guwahati
# 5                   Dhubri to Guwahati
# 6  Sibsagar (Assam) to North Lakhimpur
# 7  North Lakhimpur to Sibsagar (Assam)
# 8                   Guwahati to Dhubri
# 9            Jorhat to North Lakhimpur
#
#                                          Route_Links
# 0  https://www.redbus.in/bus-tickets/tezpur-to-gu...
# 1  https://www.redbus.in/bus-tickets/guwahati-to-...
# 2  https://www.redbus.in/bus-tickets/nagaon-to-gu...
# 3  https://www.redbus.in/bus-tickets/guwahati-to-...
# 4  https://www.redbus.in/bus-tickets/goalpara-to-...
# 5  https://www.redbus.in/bus-tickets/dhubri-to-gu...
# 6  https://www.redbus.in/bus-tickets/sibsagar-to-...
# 7  https://www.redbus.in/bus-tickets/north-lakhim...
# ...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/Assam_df.csv"
Assam_df.to_csv(path,index=False)

# %% [markdown]
# ## 9. Uttar Pradesh State Road Transport Corporation (UPSRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Uttar_Pradesh_Routes(path):
    UP_LINKS = []
    UP_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    UP_LINKS.append(href)
                text = link.text.strip()
                if text:
                    UP_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[10]/div[5]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(UP_LINKS) , list(UP_ROUTES)

UP_LINKS,UP_ROUTES = Uttar_Pradesh_Routes('//a[@class="route"]')
# Out:
# No more pages to paginate at page 1.

# %%
UP_df = pd.DataFrame({"Route_Names":UP_ROUTES,"Route_Links":UP_LINKS})
UP_df
# Out:
#                             Route_Names  \
# 0     Delhi to Bareilly (Uttar Pradesh)
# 1                      Delhi to Lucknow
# 2     Bareilly (Uttar Pradesh) to Delhi
# 3  Lucknow to Gorakhpur (uttar pradesh)
# 4      Aligarh (uttar pradesh) to Delhi
# 5   Lucknow to Prayagraj(Uttar Pradesh)
# 6      Delhi to Aligarh (uttar pradesh)
# 7                      Lucknow to Delhi
# 8   Prayagraj(Uttar Pradesh) to Lucknow
# 9  Delhi to Farrukhabad (Uttar Pradesh)
#
#                                          Route_Links
# 0  https://www.redbus.in/bus-tickets/delhi-to-bar...
# 1  https://www.redbus.in/bus-tickets/delhi-to-luc...
# 2  https://www.redbus.in/bus-tickets/bareilly-to-...
# 3  https://www.redbus.in/bus-tickets/lucknow-to-g...
# 4  https://www.redbus.in/bus-tickets/aligarh-utta...
# 5  https://www.redbus.in/bus-tickets/lucknow-to-a...
# 6  https://www.redbus.in/bus-tickets/delhi-to-ali...
# 7  https://www.redbus.in/bus-tickets/lucknow-to-d...
# ...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/UP_df.csv"
UP_df.to_csv(path,index=False)

# %% [markdown]
# ## 10. West Bengal Transport Corporation (WBTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def West_Bengal_Routes(path):
    WB_LINKS = []
    WB_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,5):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    WB_LINKS.append(href)
                text = link.text.strip()
                if text:
                    WB_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[10]/div[4]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(WB_LINKS) , list(WB_ROUTES)

WB_LINKS,WB_ROUTES = West_Bengal_Routes("//a[@class='route']")
# Out:
# No more pages to paginate at page 1.

# %%
WB_df = pd.DataFrame({"Route_Names":WB_ROUTES,"Route_Links":WB_LINKS})
WB_df
# Out:
#                                          Route_Names  \
# 0                     Digha to Barasat (West Bengal)
# 1                  Durgapur (West Bengal) to Kolkata
# 2                                   Digha to Kolkata
# 3                     Barasat (West Bengal) to Digha
# 4                  Kolkata to Durgapur (West Bengal)
# 5                                   Kolkata to Digha
# 6           Barasat (West Bengal) to Contai (Kanthi)
# 7                 Barasat (West Bengal) to Midnapore
# 8  Barasat (West Bengal) to Nandakumar (west bengal)
# 9                  Barasat (West Bengal) to Kolaghat
#
#                                          Route_Links
# 0  https://www.redbus.in/bus-tickets/digha-to-bar...
# 1  https://www.redbus.in/bus-tickets/durgapur-to-...
# 2  https://www.redbus.in/bus-tickets/digha-to-kol...
# 3  https://www.redbus.in/bus-tickets/barasat-west...
# 4  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 5  https://www.redbus.in/bus-tickets/kolkata-to-d...
# ...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/WB_df.csv"
WB_df.to_csv(path,index=False)
